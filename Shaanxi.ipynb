# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

shp1 = os.path.dirname('/home/masum/Documents/heyBro/CHN_ADM1/CHN_ADM1.shp')
shp2 = os.path.dirname('/home/masum/Documents/heyBro/CHN_ADM3/CHN_ADM3.shp')
shp3 = os.path.dirname('/home/masum/Documents/heyBro/CHN_ADM2/CHN_ADM2.shp')

states = gpd.read_file(shp1)
district = gpd.read_file(shp2)
weinan = gpd.read_file(shp)

Shaanxi = states[states['NAME'] == 'Shaanxi']
Wugong = district[district['NAME'] == 'Wugong County']
Weinan = weinan[weinan['NAME'] == 'Weinan City']
Nanzheng = district[district['NAME'] == 'Nanzheng County']

shaanxi_boundary_map = Shaanxi.boundary.plot(figsize=(18, 12), color='Black', linewidth=1)

Shaanxi.plot(ax=shaanxi_boundary_map,  color="PaleTurquoise", alpha=0.5)
Wugong.plot(ax=shaanxi_boundary_map,  color="Red")
Weinan.plot(ax=shaanxi_boundary_map,  color="#fce903")
Nanzheng.plot(ax=shaanxi_boundary_map,  color="Plum")

plt.axis('off')
plt.savefig('/home/masum/Documents/heyBro/31-05/Shaanxi.png', bbox_inches='tight', dpi=300)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

shp1 = os.path.dirname('/home/masum/Documents/heyBro/CHN_ADM1/CHN_ADM1.shp')
shp2 = os.path.dirname('/home/masum/Documents/heyBro/CHN_ADM3/CHN_ADM3.shp')
shp3 = os.path.dirname('/home/masum/Documents/heyBro/CHN_ADM2/CHN_ADM2.shp')

states = gpd.read_file(shp1)
district = gpd.read_file(shp2)
weinan = gpd.read_file(shp)

Shaanxi = states[states['NAME'] == 'Shaanxi']
Wugong = district[district['NAME'] == 'Wugong County']
Weinan = weinan[weinan['NAME'] == 'Weinan City']
Nanzheng = district[district['NAME'] == 'Nanzheng County']

shaanxi_boundary_map = Shaanxi.boundary.plot(figsize=(18, 12), color='Black', linewidth=1)

Shaanxi.plot(ax=shaanxi_boundary_map,  color="PaleTurquoise", alpha=0.5)
Wugong.plot(ax=shaanxi_boundary_map,  color="Red")
#Weinan.plot(ax=shaanxi_boundary_map,  color="#fce903")
#Nanzheng.plot(ax=shaanxi_boundary_map,  color="Plum")

#plt.axis('off')
#plt.savefig('/home/masum/Documents/heyBro/31-05/Shaanxi.png', bbox_inches='tight', dpi=300)
# Out:
# <AxesSubplot:>
